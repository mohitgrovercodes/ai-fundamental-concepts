# %%
import pandas as pd

df = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [24, 30, 22, 35],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston']
})

# %%
df = df.drop('Age', axis=1)

# %%
df.drop('City', axis=1)
# Out:
#       Name
# 0    Alice
# 1      Bob
# 2  Charlie
# 3    David

# %%
df
# Out:
#       Name         City
# 0    Alice     New York
# 1      Bob  Los Angeles
# 2  Charlie      Chicago
# 3    David      Houston
