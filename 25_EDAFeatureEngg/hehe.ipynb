# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('my_flight_price.xlsx')
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
df[df.duplicated(keep=False)]
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 33     Jet Airways      15/06/2019     Delhi      Cochin
# 49     Jet Airways      27/06/2019     Delhi      Cochin
# 73     Jet Airways      24/06/2019     Delhi      Cochin
# 81     Jet Airways      24/03/2019  Banglore   New Delhi
# 87     Jet Airways       6/06/2019     Delhi      Cochin
# ...            ...             ...       ...         ...
# 10594  Jet Airways      27/06/2019     Delhi      Cochin
# 10616  Jet Airways       1/06/2019     Delhi      Cochin
# 10634  Jet Airways       6/06/2019     Delhi      Cochin
# 10672  Jet Airways      27/06/2019     Delhi      Cochin
# 10673  Jet Airways      27/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 33     DEL → NAG → BOM → COK    14:35  12:35 16 Jun      22h     2 stops
# 49     DEL → AMD → BOM → COK    23:05  19:00 28 Jun  19h 55m     2 stops
# ...

# %%
df[df.duplicated(keep=False)].shape[0]
# Out:
# 415

# %%
key_cols = [
    "Airline",
    "Date_of_Journey",
    "Source",
    "Destination",
    "Dep_Time"
]

df[df.duplicated(subset=key_cols, keep=False)].sort_values(key_cols)
# Out:
#        Airline Date_of_Journey    Source Destination            Route  \
# 2266  Air Asia      03/03/2019  Banglore   New Delhi        BLR → DEL
# 2773  Air Asia      03/03/2019  Banglore   New Delhi        BLR → DEL
# 4851  Air Asia      03/03/2019  Banglore   New Delhi        BLR → DEL
# 9107  Air Asia      03/03/2019  Banglore   New Delhi        BLR → DEL
# 1459  Air Asia      09/03/2019  Banglore   New Delhi        BLR → DEL
# ...        ...             ...       ...         ...              ...
# 6586   Vistara       9/06/2019   Kolkata    Banglore  CCU → DEL → BLR
# 2873   Vistara       9/06/2019   Kolkata    Banglore  CCU → DEL → BLR
# 4106   Vistara       9/06/2019   Kolkata    Banglore  CCU → DEL → BLR
# 7322   Vistara       9/06/2019   Kolkata    Banglore  CCU → DEL → BLR
# 7625   Vistara       9/06/2019   Kolkata    Banglore  CCU → DEL → BLR
#
#      Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# ...

# %%
hashes = pd.util.hash_pandas_object(df, index=False)
hashes.duplicated().sum()
# Out:
# np.int64(220)

# %%
df.loc[hashes.duplicated(keep=False)]
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 33     Jet Airways      15/06/2019     Delhi      Cochin
# 49     Jet Airways      27/06/2019     Delhi      Cochin
# 73     Jet Airways      24/06/2019     Delhi      Cochin
# 81     Jet Airways      24/03/2019  Banglore   New Delhi
# 87     Jet Airways       6/06/2019     Delhi      Cochin
# ...            ...             ...       ...         ...
# 10594  Jet Airways      27/06/2019     Delhi      Cochin
# 10616  Jet Airways       1/06/2019     Delhi      Cochin
# 10634  Jet Airways       6/06/2019     Delhi      Cochin
# 10672  Jet Airways      27/06/2019     Delhi      Cochin
# 10673  Jet Airways      27/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 33     DEL → NAG → BOM → COK    14:35  12:35 16 Jun      22h     2 stops
# 49     DEL → AMD → BOM → COK    23:05  19:00 28 Jun  19h 55m     2 stops
# ...

# %%
dup_df = df[df.duplicated(keep=False)]

# %%
dup_df.shape
# Out:
# (415, 11)

# %%
dup_df["_row_hash"] = pd.util.hash_pandas_object(dup_df, index=False)
# Out:
# C:\Users\mogr1\AppData\Local\Temp\ipykernel_22792\3666866866.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dup_df["_row_hash"] = pd.util.hash_pandas_object(dup_df, index=False)

# %%
dup_df["_row_hash"].value_counts().head()
# Out:
# _row_hash
# 18039619856456918358    3
# 2004784000541655177     3
# 12324305981263051344    3
# 2125547460172462369     3
# 9866021966799979217     3
# Name: count, dtype: int64

# %%
example_hash = dup_df["_row_hash"].value_counts().index[0]

# %%
example_group = dup_df[dup_df["_row_hash"] == example_hash]
example_group
# Out:
#            Airline Date_of_Journey Source Destination                  Route  \
# 49     Jet Airways      27/06/2019  Delhi      Cochin  DEL → AMD → BOM → COK
# 4593   Jet Airways      27/06/2019  Delhi      Cochin  DEL → AMD → BOM → COK
# 10672  Jet Airways      27/06/2019  Delhi      Cochin  DEL → AMD → BOM → COK
#
#       Dep_Time  Arrival_Time Duration Total_Stops  \
# 49       23:05  19:00 28 Jun  19h 55m     2 stops
# 4593     23:05  19:00 28 Jun  19h 55m     2 stops
# 10672    23:05  19:00 28 Jun  19h 55m     2 stops
#
#                    Additional_Info  Price             _row_hash
# 49     In-flight meal not included  11150  18039619856456918358
# 4593   In-flight meal not included  11150  18039619856456918358
# 10672  In-flight meal not included  11150  18039619856456918358

# %%
example_group.nunique()
# Out:
# Airline            1
# Date_of_Journey    1
# Source             1
# Destination        1
# Route              1
# Dep_Time           1
# Arrival_Time       1
# Duration           1
# Total_Stops        1
# Additional_Info    1
# Price              1
# _row_hash          1
# dtype: int64

# %%
row1 = example_group.iloc[0]
row2 = example_group.iloc[1]

row1 == row2
# Out:
# Airline            True
# Date_of_Journey    True
# Source             True
# Destination        True
# Route              True
# Dep_Time           True
# Arrival_Time       True
# Duration           True
# Total_Stops        True
# Additional_Info    True
# Price              True
# _row_hash          True
# dtype: bool

# %%
df.loc[example_group.index].duplicated()
# Out:
# 49       False
# 4593      True
# 10672     True
# dtype: bool
